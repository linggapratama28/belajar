# %% [markdown]
# <a href="https://colab.research.google.com/github/linggapratama28/belajar/blob/main/cleaning_chat_wa.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import sqlalchemy
import pymysql

# %%
# !pip install pymysql
# Out:
# ...
#      |████████████████████████████████| 43 kB 2.1 MB/s
# ...

# %%
engine = sqlalchemy.create_engine("mysql+pymysql://root:apidokterm@54.151.246.185/dokterm?charset=utf8mb4")
conn = engine.connect()

# %%
df = pd.read_sql('select * from record_chat_wa', conn)

# %%
df.head(3)
# Out:
#    id_record_chat_wa  id_record_channel_wa  \
# 0                618                    24
# 1                619                    24
# 2                620                    24
#
#                                 chat_id                             account  \
# 0    SM33f4957fe3495bcf5ef2dde0bce16be9  ACbee4394400822f8578583ca4c4972d42
# 1    SM819458c57c71cad76a695356a488257a  ACbee4394400822f8578583ca4c4972d42
# 2  c46e6d63-fdbf-4c5e-8799-d8849aa50816  ACbee4394400822f8578583ca4c4972d42
#
#   agent    status            from              to  \
# 0   bot  received   +628983920211  +6281388365522
# 1   bot  received   +628983920211  +6281388365522
# 2   bot  received  +6281388365522   +628983920211
#
#                                                 chat  jumlah_media media  \
# 0                                               Test             0  None
# 1                                              Haloo             0  None
# ...

# %%
df.dtypes
# Out:
# id_record_chat_wa                int64
# id_record_channel_wa             int64
# chat_id                         object
# account                         object
# agent                           object
# status                          object
# from                            object
# to                              object
# chat                            object
# jumlah_media                     int64
# media                           object
# jenis                           object
# created_at              datetime64[ns]
# updated_at              datetime64[ns]
# dtype: object

# %%
df_backup = df.copy(deep=True)
#df.copy fungsinya untuk membuat salinan data frame di memori tidak di ram

# %%
df_backup.isna().mean()
#.isna() untuk menampilkan missing values dan .mean() untuk merata-rata kan jumlah missing value
# Out:
# id_record_chat_wa       0.000000
# id_record_channel_wa    0.000000
# chat_id                 0.000000
# account                 0.099298
# agent                   0.000000
# status                  0.000000
# from                    0.000000
# to                      0.000000
# chat                    0.989970
# jumlah_media            0.000000
# media                   1.000000
# jenis                   0.000000
# created_at              0.000000
# updated_at              0.000000
# dtype: float64

# %%
def missing_percentage():
    na_val = df_backup.isnull().sum() * 100 / len(df_backup)
    na_val = na_val[na_val.values > 0]
    na_val = na_val.sort_values(ascending=False)
    return na_val

# %%
missing_percentage()
# Out:
# media      100.000000
# chat        98.996991
# account      9.929789
# dtype: float64

# %%
df_backup = df.drop(columns=['media', 'chat'])

# %%
#df_backup.category_name.fillna('Entertainment', inplace=True)

# %%
df_backup['account'].value_counts()
# Out:
# ACbee4394400822f8578583ca4c4972d42    898
# Name: account, dtype: int64

# %%
df_backup['account']
# Out:
# 0      ACbee4394400822f8578583ca4c4972d42
# 1      ACbee4394400822f8578583ca4c4972d42
# 2      ACbee4394400822f8578583ca4c4972d42
# 3      ACbee4394400822f8578583ca4c4972d42
# 4                                    None
#                       ...
# 992    ACbee4394400822f8578583ca4c4972d42
# 993    ACbee4394400822f8578583ca4c4972d42
# 994    ACbee4394400822f8578583ca4c4972d42
# 995    ACbee4394400822f8578583ca4c4972d42
# 996    ACbee4394400822f8578583ca4c4972d42
# Name: account, Length: 997, dtype: object

# %%
df_backup.isnull()
# Out:
#      id_record_chat_wa  id_record_channel_wa  chat_id  account  agent  status  \
# 0                False                 False    False    False  False   False
# 1                False                 False    False    False  False   False
# 2                False                 False    False    False  False   False
# 3                False                 False    False    False  False   False
# 4                False                 False    False     True  False   False
# ..                 ...                   ...      ...      ...    ...     ...
# 992              False                 False    False    False  False   False
# 993              False                 False    False    False  False   False
# 994              False                 False    False    False  False   False
# 995              False                 False    False    False  False   False
# 996              False                 False    False    False  False   False
#
# ...

# %%
df_backup.loc[:, df_backup.isnull().any()].columns
# Out:
# Index(['account'], dtype='object')

# %%
df_backup.isnull().iloc[0:997, :]
# Out:
#      id_record_chat_wa  id_record_channel_wa  chat_id  account  agent  status  \
# 0                False                 False    False    False  False   False
# 1                False                 False    False    False  False   False
# 2                False                 False    False    False  False   False
# 3                False                 False    False    False  False   False
# 4                False                 False    False     True  False   False
# ..                 ...                   ...      ...      ...    ...     ...
# 992              False                 False    False    False  False   False
# 993              False                 False    False    False  False   False
# 994              False                 False    False    False  False   False
# 995              False                 False    False    False  False   False
# 996              False                 False    False    False  False   False
#
# ...

# %%
df_backup.loc[df_backup.account.isnull()]
# Out:
#      id_record_chat_wa  id_record_channel_wa  \
# 4                  622                    24
# 6                  624                    24
# 9                  627                    24
# 35                 653                    26
# 54                 672                    27
# 65                 683                    28
# 68                 686                    28
# 81                 699                    29
# 93                 711                    30
# 94                 712                    30
# 95                 713                    30
# 115                733                    31
# 161                779                    32
# 195                813                    33
# 196                814                    33
# 197                815                    33
# 202                820                    34
# 205                823                    35
# 207                825                    35
# 208                826                    35
# ...
