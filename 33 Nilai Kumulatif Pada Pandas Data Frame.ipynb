# %%
import pandas as pd

# %% [markdown]
# ## Persiapan Data Frame

# %%
d = {'pemain' : ['Budi', 'Joni', 'Iwan', 'Budi', 'Budi', 'Iwan', 'Asep', 'Joni'],
     'goal' : [2, 1, 3, 1, 1, 2, 2, 3]}
df = pd.DataFrame(d)
df
# Out:
#   pemain  goal
# 0   Budi     2
# 1   Joni     1
# 2   Iwan     3
# 3   Budi     1
# 4   Budi     1
# 5   Iwan     2
# 6   Asep     2
# 7   Joni     3

# %% [markdown]
# ## Menampilkan Nilai Kumulatif (cummulative)

# %%
df['goal'].cumsum().to_frame()
# Out:
#    goal
# 0     2
# 1     3
# 2     6
# 3     7
# 4     8
# 5    10
# 6    12
# 7    15

# %%
df['jumlah_goal_kumulatif'] = df['goal'].cumsum()
df
# index ke 4 jumlah goal kumulatifnya ada 8. di hitung dari index 0 - index 4 kemudian di jumlah. atau seperti 2 + 1 + 3 + 1 + 1
# Out:
#   pemain  goal  jumlah_goal_kumulatif
# 0   Budi     2                      2
# 1   Joni     1                      3
# 2   Iwan     3                      6
# 3   Budi     1                      7
# 4   Budi     1                      8
# 5   Iwan     2                     10
# 6   Asep     2                     12
# 7   Joni     3                     15

# %%
df['jumlah_goal_kumulatif_tiap_pemain'] = df.groupby('pemain')['goal'].cumsum()
df
# Out:
#   pemain  goal  jumlah_goal_kumulatif  jumlah_goal_kumulatif_tiap_pemain
# 0   Budi     2                      2                                  2
# 1   Joni     1                      3                                  1
# 2   Iwan     3                      6                                  3
# 3   Budi     1                      7                                  3
# 4   Budi     1                      8                                  4
# 5   Iwan     2                     10                                  5
# 6   Asep     2                     12                                  2
# 7   Joni     3                     15                                  4

# %%
df['cummax'] = df['goal'].cummax()
df
# fugsi cummax adalah mencari nilai tertinggi. contohnya nyari nilai tertinggi dari index 0-5 maka jawabannya adalah 3
# Out:
#   pemain  goal  jumlah_goal_kumulatif  jumlah_goal_kumulatif_tiap_pemain  \
# 0   Budi     2                      2                                  2
# 1   Joni     1                      3                                  1
# 2   Iwan     3                      6                                  3
# 3   Budi     1                      7                                  3
# 4   Budi     1                      8                                  4
# 5   Iwan     2                     10                                  5
# 6   Asep     2                     12                                  2
# 7   Joni     3                     15                                  4
#
#    cummax
# 0       2
# 1       2
# 2       3
# 3       3
# 4       3
# 5       3
# 6       3
# 7       3

# %%
df['cummin'] = df['goal'].cummin()
df
# Out:
#   pemain  goal  jumlah_goal_kumulatif  jumlah_goal_kumulatif_tiap_pemain  \
# 0   Budi     2                      2                                  2
# 1   Joni     1                      3                                  1
# 2   Iwan     3                      6                                  3
# 3   Budi     1                      7                                  3
# 4   Budi     1                      8                                  4
# 5   Iwan     2                     10                                  5
# 6   Asep     2                     12                                  2
# 7   Joni     3                     15                                  4
#
#    cummax  cummin
# 0       2       2
# 1       2       1
# 2       3       1
# 3       3       1
# 4       3       1
# 5       3       1
# 6       3       1
# 7       3       1

# %%
df['cumprod'] = df['goal'].cumprod()
df
# fungsi cumprod adalah hasil total perkalian. contohnya mencari nilai cumprod dari index 4. maka index dari 0 - 4 di kalikan
# Out:
#   pemain  goal  jumlah_goal_kumulatif  jumlah_goal_kumulatif_tiap_pemain  \
# 0   Budi     2                      2                                  2
# 1   Joni     1                      3                                  1
# 2   Iwan     3                      6                                  3
# 3   Budi     1                      7                                  3
# 4   Budi     1                      8                                  4
# 5   Iwan     2                     10                                  5
# 6   Asep     2                     12                                  2
# 7   Joni     3                     15                                  4
#
#    cummax  cummin  cumprod
# 0       2       2        2
# 1       2       1        2
# 2       3       1        6
# 3       3       1        6
# 4       3       1        6
# 5       3       1       12
# 6       3       1       24
# 7       3       1       72
